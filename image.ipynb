# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
#Load the image
img=Image.open("/content/ac.jpg").convert("L")
# convert the image to NUMPY array
arr=np.array(img)*255
print(arr.shape)
print(arr)
#convert the Numpy array to image
plt.imshow(arr,cmap="gray")
plt.axis("off")
plt.show()
# Out:
# (736, 736)
# [[116 116 116 ... 112 112 112]
#  [116 116 116 ... 113 113 113]
#  [116 116 116 ... 113 113 113]
#  ...
#  [ 94  94  94 ...  82  83  85]
#  [ 82  82  82 ...  69  71  73]
#  [151 151 151 ... 142 144 145]]
